# %% [markdown]
# # Analyse results

# %% [markdown]
# Full scenario with load shedding enabled

# %% [markdown]
# Useful references:
# * https://pypsa.readthedocs.io/en/latest/examples/scigrid-lopf-then-pf.html (example from PyPSA documentation with many different visualisations)

# %% [markdown]
# ## Setup and helpers

# %%
import cartopy.crs as ccrs
import cartopy.feature as cfeature
import matplotlib.pyplot as plt
import pypsa
import yaml

# plotting settings
plt.style.use('ggplot') # what is this?
plt.rcParams['figure.figsize'] = (6, 6)
projection = ccrs.LambertAzimuthalEqualArea(central_longitude=10, central_latitude=52) # good for Europe

# Load the network
run_name = "02-28_2"
scenario_name = "full"
file = "base_s_2_elec_68H-Co2L.nc"
base_path = f"../results/{run_name}/{scenario_name}"
network_file = f"{base_path}/networks/{file}"
network = pypsa.Network(network_file)

# Load the config file
with open("../config/config.yaml") as stream:
    config = yaml.safe_load(stream)

def plot_europe(ax):
    ax.set_extent([-10, 40, 35, 70], crs=ccrs.PlateCarree()) # Europe
    ax.add_feature(cfeature.BORDERS, linestyle=':')
    ax.add_feature(cfeature.COASTLINE, edgecolor='black')
    ax.add_feature(cfeature.LAND, facecolor='lightgrey')
    ax.add_feature(cfeature.LAKES, facecolor='lightblue', alpha=0.8)
    ax.add_feature(cfeature.RIVERS, edgecolor='lightblue', alpha=0.8)

    gl = ax.gridlines(draw_labels=True, color="gray", alpha=0.5, linestyle="--")
    gl.top_labels = False  # Disable top labels
    gl.right_labels = False  # Disable right labels
# Out:
# INFO:pypsa.io:Imported network base_s_2_elec_68H-Co2L.nc has buses, carriers, generators, global_constraints, lines, links, loads, storage_units, stores

# %% [markdown]
# ## Export static and dynamic components

# %%
network.export_to_csv_folder(f"{base_path}/tables/")
# Out:
# INFO:pypsa.io:Exported network '<unnamed>' contains: loads, carriers, links, buses, global_constraints, storage_units, stores, generators, lines

# %% [markdown]
# ## Inspect network object
#
# All the possible components within a network are given in https://pypsa.readthedocs.io/en/latest/user-guide/components.html

# %% [markdown]
# ### All components

# %%
network.df  # simply describes types of components available in the network
# Out:
# <bound method Network.df of Unnamed PyPSA Network
# ---------------------
# Components:
#  - Bus: 4
#  - Carrier: 16
#  - Generator: 14
#  - GlobalConstraint: 1
#  - Line: 1
#  - Link: 4
#  - Load: 2
#  - StorageUnit: 5
#  - Store: 2
# Snapshots: 129>

# %% [markdown]
# ### Loads

# %%
network.loads
# Out:
#          bus carrier type  p_set  q_set  sign  active
# Load
# CH0 0  CH0 0                 0.0    0.0  -1.0    True
# DE0 0  DE0 0                 0.0    0.0  -1.0    True

# %% [markdown]
# ### Buses

# %%
network.component_attrs.Bus # look at component attributes if you need to know units, etc.
# Out:
#                             type          unit default  \
# attribute
# name                      string           NaN
# v_nom                      float            kV     1.0
# type                      string           NaN
# x                          float           NaN     0.0
# y                          float           NaN     0.0
# carrier                   string           NaN      AC
# unit                      string           NaN
# v_mag_pu_set    static or series      per unit     1.0
# v_mag_pu_min               float      per unit     0.0
# v_mag_pu_max               float      per unit     inf
# control                   string           NaN      PQ
# generator                 string           NaN
# sub_network               string           NaN
# p                         series            MW     0.0
# q                         series          MVar     0.0
# v_mag_pu                  series      per unit     1.0
# v_ang                     series       radians     0.0
# marginal_price            series  currency/MWh     0.0
#
#                                                       description  \
# attribute
# name                                                  Unique name
# v_nom                                             Nominal voltage
# type               Placeholder for bus type. Not yet implemented.
# x               Position (e.g. longitude); the Spatial Referen...
# y               Position (e.g. latitude); the Spatial Referenc...
# carrier         Energy carrier: can be "AC" or "DC" for electr...
# unit            Unit of the bus’ carrier if the implicitly ass...
# v_mag_pu_set      Voltage magnitude set point, per unit of v_nom.
# v_mag_pu_min    Minimum desired voltage, per unit of v_nom. Th...
# v_mag_pu_max    Maximum desired voltage, per unit of v_nom.  T...
# control         P,Q,V control strategy for PF, must be "PQ", "...
# generator          Name of slack generator attached to slack bus.
# sub_network     Name of connected sub-network to which bus bel...
# p               active power at bus (positive if net generatio...
# q               reactive power (positive if net generation at ...
# v_mag_pu                     Voltage magnitude, per unit of v_nom
# v_ang                                               Voltage angle
# marginal_price  Locational marginal price from LOPF from power...
#
#                           status  static  varying              typ    dtype
# attribute
# name            Input (required)    True    False    <class 'str'>   object
# v_nom           Input (optional)    True    False  <class 'float'>  float64
# type            Input (optional)    True    False    <class 'str'>   object
# x               Input (optional)    True    False  <class 'float'>  float64
# y               Input (optional)    True    False  <class 'float'>  float64
# carrier         Input (optional)    True    False    <class 'str'>   object
# unit            Input (optional)    True    False    <class 'str'>   object
# v_mag_pu_set    Input (optional)    True     True  <class 'float'>  float64
# v_mag_pu_min    Input (optional)    True    False  <class 'float'>  float64
# v_mag_pu_max    Input (optional)    True    False  <class 'float'>  float64
# control                   Output    True    False    <class 'str'>   object
# generator                 Output    True    False    <class 'str'>   object
# sub_network               Output    True    False    <class 'str'>   object
# p                         Output   False     True  <class 'float'>  float64
# q                         Output   False     True  <class 'float'>  float64
# v_mag_pu                  Output   False     True  <class 'float'>  float64
# v_ang                     Output   False     True  <class 'float'>  float64
# marginal_price            Output   False     True  <class 'float'>  float64

# %%
network.buses
# Out:
#           v_nom type         x          y carrier unit  v_mag_pu_set  \
# Bus
# CH0 0     380.0       8.297643  46.894102      AC                1.0
# DE0 0     380.0       9.202027  51.085260      AC                1.0
# CH0 0 H2    1.0       8.297643  46.894102      H2                1.0
# DE0 0 H2    1.0       9.202027  51.085260      H2                1.0
#
#           v_mag_pu_min  v_mag_pu_max control         generator sub_network  \
# Bus
# CH0 0              0.0           inf      PQ
# DE0 0              0.0           inf   Slack  DE0 0 offwind-ac
# CH0 0 H2           0.0           inf      PQ
# DE0 0 H2           0.0           inf      PQ
#
#           substation_lv country location  substation_off
# Bus
# CH0 0               1.0      CH                      1.0
# DE0 0               1.0      DE                      1.0
# CH0 0 H2            NaN      CH    CH0 0             NaN
# DE0 0 H2            NaN      DE    DE0 0             NaN

# %% [markdown]
# ### Carriers

# %%
network.component_attrs.Carrier
# Out:
#                        type        unit default  \
# attribute
# name                 string         NaN
# co2_emissions         float  tonnes/MWh     0.0
# color                string         NaN
# nice_name            string         NaN
# max_growth            float          MW     inf
# max_relative_growth   float          MW     0.0
#
#                                                            description  \
# attribute
# name                                                       Unique name
# co2_emissions        Emissions in CO2-tonnes-equivalent per MWh of ...
# color                                                   plotting color
# nice_name                                More precise descriptive name
# max_growth           maximum new installed capacity per investment ...
# max_relative_growth  maximum capacity ratio for new installed capac...
#
#                                status  static  varying              typ  \
# attribute
# name                 Input (required)    True    False    <class 'str'>
# co2_emissions        Input (optional)    True    False  <class 'float'>
# color                Input (optional)    True    False    <class 'str'>
# nice_name            Input (optional)    True    False    <class 'str'>
# max_growth           Input (optional)    True    False  <class 'float'>
# max_relative_growth  Input (optional)    True    False  <class 'float'>
#
#                        dtype
# attribute
# name                  object
# co2_emissions        float64
# color                 object
# nice_name             object
# max_growth           float64
# max_relative_growth  float64

# %%
network.carriers
# Out:
#                  co2_emissions    color             nice_name  max_growth  \
# Carrier
# DC                         0.0  #8a1caf                    DC         inf
# AC                         0.0  #70af1d                    AC         inf
# offwind-ac                 0.0  #6895dd    Offshore Wind (AC)         inf
# solar                      0.0  #f9d002                 Solar         inf
# offwind-dc                 0.0  #74c6f2    Offshore Wind (DC)         inf
# hydro                      0.0  #298c81       Reservoir & Dam         inf
# onwind                     0.0  #235ebc          Onshore Wind         inf
# ror                        0.0  #3dbfb0          Run of River         inf
# PHS                        0.0  #51dbcc  Pumped Hydro Storage         inf
# battery                    0.0  #ace37f       Battery Storage         inf
# H2                         0.0  #bf13a0      Hydrogen Storage         inf
#                            0.0                                        inf
# H2 fuel cell               0.0  #c251ae          H2 fuel cell         inf
# H2 electrolysis            0.0  #ff29d9       H2 electrolysis         inf
# load                       0.0  #dd2e23         Load shedding         inf
# curtailment                0.0  #fedfed           Curtailment         inf
#
#                  max_relative_growth
# Carrier
# DC                               0.0
# AC                               0.0
# offwind-ac                       0.0
# solar                            0.0
# offwind-dc                       0.0
# hydro                            0.0
# onwind                           0.0
# ror                              0.0
# PHS                              0.0
# battery                          0.0
# H2                               0.0
#                                  0.0
# H2 fuel cell                     0.0
# H2 electrolysis                  0.0
# load                             0.0
# curtailment                      0.0

# %% [markdown]
# ### Generators

# %%
network.generators[["bus", "carrier", "p_nom_opt", "p_nom_max", "p_nom_min", "marginal_cost"]]
# generators con
# Out:
#                         bus      carrier     p_nom_opt     p_nom_max  \
# Generator
# DE0 0 offwind-ac      DE0 0   offwind-ac  4.179646e+03  4.179646e+03
# CH0 0 solar           CH0 0        solar  1.253695e+05  1.253695e+05
# DE0 0 solar           DE0 0        solar  1.652112e+05  1.086693e+06
# DE0 0 offwind-dc      DE0 0   offwind-dc  2.175411e+04  2.175411e+04
# CH0 0 onwind          CH0 0       onwind  7.445521e-13  7.697001e+04
# DE0 0 onwind          DE0 0       onwind  1.056938e+05  4.878369e+05
# CH0 0 ror             CH0 0          ror  4.202621e+03           inf
# DE0 0 ror             DE0 0          ror  5.237029e+03           inf
# CH0 0 load            CH0 0         load  1.000000e+09           inf
# DE0 0 load            DE0 0         load  1.000000e+09           inf
# CH0 0 H2 load      CH0 0 H2         load  1.000000e+09           inf
# DE0 0 H2 load      DE0 0 H2         load  1.000000e+09           inf
# CH0 0 curtailment     CH0 0  curtailment  1.000000e+06           inf
# DE0 0 curtailment     DE0 0  curtailment  1.000000e+06           inf
#
#                    p_nom_min  marginal_cost
# Generator
# DE0 0 offwind-ac         0.0          0.015
# CH0 0 solar              0.0          0.010
# DE0 0 solar              0.0          0.010
# DE0 0 offwind-dc         0.0          0.015
# CH0 0 onwind             0.0          0.015
# DE0 0 onwind             0.0          0.015
# CH0 0 ror                0.0          0.000
# DE0 0 ror                0.0          0.000
# CH0 0 load               0.0          1.000
# DE0 0 load               0.0          1.000
# CH0 0 H2 load            0.0          1.000
# DE0 0 H2 load            0.0          1.000
# CH0 0 curtailment        0.0         -0.100
# DE0 0 curtailment        0.0         -0.100

# %%
network.component_attrs.Generator # nice table of all attributes of generators
# Out:
#                                      type          unit default  \
# attribute
# name                               string           NaN
# bus                                string           NaN
# control                            string           NaN      PQ
# type                               string           NaN
# p_nom                               float            MW     0.0
# p_nom_mod                           float            MW     0.0
# p_nom_extendable                  boolean           NaN   False
# p_nom_min                           float            MW     0.0
# p_nom_max                           float            MW     inf
# p_min_pu                 static or series      per unit     0.0
# p_max_pu                 static or series      per unit     1.0
# p_set                    static or series            MW     0.0
# e_sum_min                           float           MWh    -inf
# e_sum_max                           float           MWh     inf
# q_set                    static or series          MVar     0.0
# sign                                float           NaN     1.0
# carrier                            string           NaN
# marginal_cost            static or series  currency/MWh     0.0
# marginal_cost_quadratic  static or series  currency/MWh     0.0
# active                            boolean           NaN    True
# build_year                            int          year       0
# lifetime                            float         years     inf
# capital_cost                        float   currency/MW     0.0
# efficiency               static or series      per unit     1.0
# committable                       boolean           NaN   False
# start_up_cost                       float      currency     0.0
# shut_down_cost                      float      currency     0.0
# stand_by_cost            static or series    currency/h     0.0
# min_up_time                           int     snapshots       0
# min_down_time                         int     snapshots       0
# up_time_before                        int     snapshots       1
# down_time_before                      int     snapshots       0
# ramp_limit_up            static or series      per unit     NaN
# ramp_limit_down          static or series      per unit     NaN
# ramp_limit_start_up                 float      per unit     1.0
# ramp_limit_shut_down                float      per unit     1.0
# weight                              float           NaN     1.0
# p                                  series            MW     0.0
# q                                  series          MVar     0.0
# p_nom_opt                           float            MW     0.0
# status                             series           NaN     1.0
# mu_upper                           series  currency/MWh     0.0
# mu_lower                           series  currency/MWh     0.0
# mu_p_set                           series  currency/MWh     0.0
# mu_ramp_limit_up                   series  currency/MWh     0.0
# mu_ramp_limit_down                 series  currency/MWh     0.0
#
#                                                                description  \
# attribute
# name                                                           Unique name
# bus                             name of bus to which generator is attached
# control                  P,Q,V control strategy for PF, must be "PQ", "...
# type                     Placeholder for generator type. Not yet implem...
# p_nom                            Nominal power for limits in optimization.
# p_nom_mod                           Nominal power of the generator module.
# p_nom_extendable         Switch to allow capacity p_nom to be extended ...
# p_nom_min                If p_nom is extendable in optimization, set it...
# p_nom_max                If p_nom is extendable in optimization, set it...
# p_min_pu                 The minimum output for each snapshot per unit ...
# p_max_pu                 The maximum output for each snapshot per unit ...
# p_set                                      active power set point (for PF)
# e_sum_min                The minimum total energy produced during a sin...
# e_sum_max                The maximum total energy produced during a sin...
# q_set                                    reactive power set point (for PF)
# sign                                                            power sign
# carrier                  Prime mover energy carrier (e.g. coal, gas, wi...
# marginal_cost                        Marginal cost of production of 1 MWh.
# marginal_cost_quadratic    Quadratic marginal cost of production of 1 MWh.
# active                   Whether to consider the component in basic fun...
# build_year                                                      build year
# lifetime                                                          lifetime
# capital_cost             Fixed period costs of extending p_nom by 1 MW,...
# efficiency               Ratio between primary energy and electrical en...
# committable              Use unit commitment (only possible if p_nom is...
# start_up_cost            Cost to start up the generator. Only read if c...
# shut_down_cost           Cost to shut down the generator. Only read if ...
# stand_by_cost            Stand-by cost for operating the generator at n...
# min_up_time              Minimum number of snapshots for status to be 1...
# min_down_time            Minimum number of snapshots for status to be 0...
# up_time_before           Number of snapshots that the generator was onl...
# down_time_before         Number of snapshots that the generator was off...
# ramp_limit_up            Maximum active power increase from one snapsho...
# ramp_limit_down          Maximum active power decrease from one snapsho...
# ramp_limit_start_up      Maximum active power increase at start up, per...
# ramp_limit_shut_down     Maximum active power decrease at shut down, pe...
# weight                   Weighting of a generator. Only used for networ...
# p                         active power at bus (positive if net generation)
# q                              reactive power (positive if net generation)
# p_nom_opt                                         Optimised nominal power.
# status                   Status (1 is on, 0 is off). Only outputted if ...
# mu_upper                                 Shadow price of upper p_nom limit
# mu_lower                                 Shadow price of lower p_nom limit
# mu_p_set                      Shadow price of fixed power generation p_set
# mu_ramp_limit_up                       Shadow price of upper ramp up limit
# mu_ramp_limit_down                   Shadow price of lower ramp down limit
#
#                                    status  static  varying              typ  \
# attribute
# name                     Input (required)    True    False    <class 'str'>
# bus                      Input (required)    True    False    <class 'str'>
# control                  Input (optional)    True    False    <class 'str'>
# type                     Input (optional)    True    False    <class 'str'>
# p_nom                    Input (optional)    True    False  <class 'float'>
# p_nom_mod                Input (optional)    True    False  <class 'float'>
# p_nom_extendable         Input (optional)    True    False   <class 'bool'>
# p_nom_min                Input (optional)    True    False  <class 'float'>
# p_nom_max                Input (optional)    True    False  <class 'float'>
# p_min_pu                 Input (optional)    True     True  <class 'float'>
# p_max_pu                 Input (optional)    True     True  <class 'float'>
# p_set                    Input (optional)    True     True  <class 'float'>
# e_sum_min                Input (optional)    True    False  <class 'float'>
# e_sum_max                Input (optional)    True    False  <class 'float'>
# q_set                    Input (optional)    True     True  <class 'float'>
# sign                     Input (optional)    True    False  <class 'float'>
# carrier                  Input (optional)    True    False    <class 'str'>
# marginal_cost            Input (optional)    True     True  <class 'float'>
# marginal_cost_quadratic  Input (optional)    True     True  <class 'float'>
# active                   Input (optional)    True    False   <class 'bool'>
# build_year               Input (optional)    True    False    <class 'int'>
# lifetime                 Input (optional)    True    False  <class 'float'>
# capital_cost             Input (optional)    True    False  <class 'float'>
# efficiency               Input (optional)    True     True  <class 'float'>
# committable              Input (optional)    True    False   <class 'bool'>
# start_up_cost            Input (optional)    True    False  <class 'float'>
# shut_down_cost           Input (optional)    True    False  <class 'float'>
# stand_by_cost            Input (optional)    True     True  <class 'float'>
# min_up_time              Input (optional)    True    False    <class 'int'>
# min_down_time            Input (optional)    True    False    <class 'int'>
# up_time_before           Input (optional)    True    False    <class 'int'>
# down_time_before         Input (optional)    True    False    <class 'int'>
# ramp_limit_up            Input (optional)    True     True  <class 'float'>
# ramp_limit_down          Input (optional)    True     True  <class 'float'>
# ramp_limit_start_up      Input (optional)    True    False  <class 'float'>
# ramp_limit_shut_down     Input (optional)    True    False  <class 'float'>
# weight                   Input (optional)    True    False  <class 'float'>
# p                                  Output   False     True  <class 'float'>
# q                                  Output   False     True  <class 'float'>
# p_nom_opt                          Output    True    False  <class 'float'>
# status                             Output   False     True  <class 'float'>
# mu_upper                           Output   False     True  <class 'float'>
# mu_lower                           Output   False     True  <class 'float'>
# mu_p_set                           Output   False     True  <class 'float'>
# mu_ramp_limit_up                   Output   False     True  <class 'float'>
# mu_ramp_limit_down                 Output   False     True  <class 'float'>
#
#                            dtype
# attribute
# name                      object
# bus                       object
# control                   object
# type                      object
# p_nom                    float64
# p_nom_mod                float64
# p_nom_extendable            bool
# p_nom_min                float64
# p_nom_max                float64
# p_min_pu                 float64
# p_max_pu                 float64
# p_set                    float64
# e_sum_min                float64
# e_sum_max                float64
# q_set                    float64
# sign                     float64
# carrier                   object
# marginal_cost            float64
# marginal_cost_quadratic  float64
# active                      bool
# build_year                 int64
# lifetime                 float64
# capital_cost             float64
# efficiency               float64
# committable                 bool
# start_up_cost            float64
# shut_down_cost           float64
# stand_by_cost            float64
# min_up_time                int64
# min_down_time              int64
# up_time_before             int64
# down_time_before           int64
# ramp_limit_up            float64
# ramp_limit_down          float64
# ramp_limit_start_up      float64
# ramp_limit_shut_down     float64
# weight                   float64
# p                        float64
# q                        float64
# p_nom_opt                float64
# status                   float64
# mu_upper                 float64
# mu_lower                 float64
# mu_p_set                 float64
# mu_ramp_limit_up         float64
# mu_ramp_limit_down       float64

# %% [markdown]
# ### Storage Units

# %%
network.storage_units[["bus", "carrier", "p_nom_opt", "p_nom_max", "p_nom_min", "marginal_cost"]] # no energy columns
# Out:
#                  bus  carrier     p_nom_opt  p_nom_max  p_nom_min  \
# StorageUnit
# CH0 0 PHS      CH0 0      PHS  5.107550e+03        inf        0.0
# DE0 0 PHS      DE0 0      PHS  7.469346e+03        inf        0.0
# CH0 0 hydro    CH0 0    hydro  1.080487e+04        inf        0.0
# CH0 0 battery  CH0 0  battery  5.303813e-10        inf        0.0
# DE0 0 battery  DE0 0  battery  6.032870e-10        inf        0.0
#
#                marginal_cost
# StorageUnit
# CH0 0 PHS                0.0
# DE0 0 PHS                0.0
# CH0 0 hydro              0.0
# CH0 0 battery            0.0
# DE0 0 battery            0.0

# %% [markdown]
# ### Storage

# %%
network.stores[['bus', 'carrier', 'e_nom_opt', 'e_nom_max', 'e_nom_min', 'marginal_cost']] # no power columns
# Out:
#                bus carrier     e_nom_opt  e_nom_max  e_nom_min  marginal_cost
# Store
# CH0 0 H2  CH0 0 H2      H2  3.386573e-07        inf        0.0            0.0
# DE0 0 H2  DE0 0 H2      H2  2.767991e+07        inf        0.0            0.0

# %% [markdown]
# ### Constraints

# %%
network.component_attrs.GlobalConstraint
# Out:
#                      type               unit         default  \
# attribute
# name               string                NaN
# type               string                NaN  primary_energy
# investment_period   float                NaN             NaN
# carrier_attribute  string                NaN   co2_emissions
# sense              string                NaN              ==
# constant            float                NaN             0.0
# mu                  float  currency/constant             0.0
#
#                                                          description  \
# attribute
# name                                                     Unique name
# type               Type of constraint (only "primary energy", i.e...
# investment_period  time period when the constraint is applied, if...
# carrier_attribute  If the global constraint is connected with an ...
# sense                  Constraint sense; must be one of <=, == or >=
# constant           Constant for right-hand-side of constraint for...
# mu                                 Shadow price of global constraint
#
#                              status  static  varying              typ    dtype
# attribute
# name               Input (required)    True    False    <class 'str'>   object
# type               Input (optional)    True    False    <class 'str'>   object
# investment_period  Input (optional)    True    False  <class 'float'>  float64
# carrier_attribute  Input (optional)    True    False    <class 'str'>   object
# sense              Input (optional)    True    False    <class 'str'>   object
# constant           Input (optional)    True    False  <class 'float'>  float64
# mu                           Output    True    False  <class 'float'>  float64

# %% [markdown]
# ## Static variables
# Not dependent on t

# %% [markdown]
# ### Network map

# %%
l_by_bus = network.loads_t.p.mean()

fig, ax = plt.subplots(subplot_kw={"projection": projection})
network.plot(ax=ax, bus_sizes=l_by_bus*1e-5, title="Load by bus")
plot_europe(ax)
# Out:
# /Users/jopeel/miniconda3/envs/pypsa-eur/lib/python3.12/site-packages/cartopy/mpl/feature_artist.py:144: UserWarning: facecolor will have no effect as it has been defined as "never".
#   warnings.warn('facecolor will have no effect as it has been '

# %% [markdown]
# ### Capacities

# %%
installed_generators = network.generators.groupby("carrier")["p_nom_opt"].sum()
installed_storage_units = network.storage_units.groupby("carrier")["p_nom_opt"].sum()

fig, ax = plt.subplots(2, 1, figsize=(10, 10))

installed_generators.plot(kind="bar", ax=ax[0])
ax[0].set_ylabel("Installed capacity [MW]")
ax[0].set_title("Installed generator capacity by carrier")

installed_storage_units.plot(kind="bar", ax=ax[1])
ax[1].set_ylabel("Installed capacity [MW]")
ax[1].set_title("Installed storage capacity by carrier")

plt.tight_layout()

# %% [markdown]
# ### Costs

# %%
capital_costs = network.generators.capital_cost.sort_index().div(1e6) # M€/MW
capital_costs_installed = (capital_costs * network.generators.p_nom_opt) # M€
marginal_costs = network.generators.marginal_cost.sort_index() # €/MWh

time_interval = (network.snapshots[1] - network.snapshots[0]).total_seconds() / 3600 # hours
energy_produced = network.generators_t.p.sum() * time_interval # MWh
marginal_costs_total = (network.generators.marginal_cost * network.generators_t.p).sum() / 1e6 # M€

fig, ax = plt.subplots(4, 1, figsize=(10, 15))

capital_costs.plot(kind="barh", ax=ax[0], title="Capital costs per generator", color="skyblue")
ax[0].set_xlabel("Capital costs [M€/MW]")
ax[0].set_ylabel("Generator")

# plot total capital costs of installed generators by multiplying by p_nom_opt
capital_costs_installed.plot(kind="barh", ax=ax[1], title="Total capital costs of installed generators", color="blue")
ax[1].set_xlabel("Capital costs [M€]")
ax[1].set_ylabel("Generator")

# barplot of marginal costs per generator
marginal_costs.plot(kind="barh", ax=ax[2], title="Marginal costs per generator", color="skyblue")
ax[2].set_xlabel("Marginal costs [€/MWh]")
ax[2].set_ylabel("Generator")

# barplot of total marginal costs
marginal_costs_total.plot(kind="barh", ax=ax[3], title="Total marginal costs", color="blue")
ax[3].set_xlabel("Marginal costs [M€]")
ax[3].set_ylabel("Generator")

plt.tight_layout()
plt.show()

capex = (
    (network.generators.p_nom_opt * network.generators.capital_cost).sum()
    + (network.links.p_nom_opt * network.links.capital_cost).sum()
    + (network.storage_units.p_nom_opt * network.storage_units.capital_cost).sum()
) / 1e9  # Convert to billion EUR

print(f"Total Capital Cost: {capex:.2f} billion EUR")

opex = (
    (network.generators_t.p * network.generators.marginal_cost).sum().sum()
) / 1e9  # Convert to billion EUR

print(f"Total Operational Cost: {opex:.2f} billion EUR")
# Out:
# Total Capital Cost: 41.28 billion EUR
# Total Operational Cost: 0.02 billion EUR

# %% [markdown]
# ## Dynamic variables

# %% [markdown]
# Display simultaneously:
# * demand (load)
# * generator dispatch
# * storage consumption and production

# %%
load_p_by_bus = network.loads_t.p.div(1e3)
gen_p_by_gen = network.generators_t.p.div(1e3)
# gen_p_by_gen = gen_p_by_gen.drop(columns=gen_p_by_gen.filter(like="load").columns) # drop load generators
price_by_bus = network.buses_t.marginal_price.div(1e3) # in €/kWh
p_by_bus = network.buses_t.p.div(1e3)
storage_units_inflow_by_unit = network.storage_units_t.inflow.div(1e3)
storage_units_p_by_unit = network.storage_units_t.p.div(1e3)
storage_units_e_by_unit = network.storage_units_t.state_of_charge.div(1e3)
stores_p_by_store = network.stores_t.p.div(1e3)
store_e_by_store = network.stores_t.e.div(1e3)

# plot all
fig, ax = plt.subplots(9, 1, figsize=(10, 25))

load_p_by_bus.plot(ax=ax[0])
ax[0].set_title("Load")
ax[0].set_ylabel("Power [GW]")
ax[0].legend(loc='center left', bbox_to_anchor=(1, 0.5))

gen_p_by_gen.plot(ax=ax[1])
ax[1].set_title("Generation")
ax[1].set_ylabel("Power [GW]")
ax[1].legend(loc='center left', bbox_to_anchor=(1, 0.5))

price_by_bus.plot(ax=ax[2])
ax[2].set_title("Price by bus")
ax[2].set_ylabel("Price [€/kWh]")
ax[2].legend(loc='center left', bbox_to_anchor=(1, 0.5))

p_by_bus.plot(ax=ax[3])
ax[3].set_title("Net power by bus")
ax[3].set_ylabel("Power [GW]")
ax[3].legend(loc='center left', bbox_to_anchor=(1, 0.5))

storage_units_inflow_by_unit.plot(ax=ax[4])
ax[4].set_title("Storage units inflow")
ax[4].set_ylabel("Power [GW]")
ax[4].legend(loc='center left', bbox_to_anchor=(1, 0.5))

storage_units_p_by_unit.plot(ax=ax[5])
ax[5].set_title("Storage units power")
ax[5].set_ylabel("Power [GW]")
ax[5].legend(loc='center left', bbox_to_anchor=(1, 0.5))

storage_units_e_by_unit.plot(ax=ax[6])
ax[6].set_title("Storage units energy")
ax[6].set_ylabel("Stored energy [GWh]")
ax[6].legend(loc='center left', bbox_to_anchor=(1, 0.5))

stores_p_by_store.plot(ax=ax[7])
ax[7].set_title("Storage power")
ax[7].set_ylabel("Power [GW]")
ax[7].legend(loc='center left', bbox_to_anchor=(1, 0.5))

store_e_by_store.plot(ax=ax[8])
ax[8].set_title("Storage energy")
ax[8].set_ylabel("Stored energy [GWh]")
ax[8].legend(loc='center left', bbox_to_anchor=(1, 0.5))

plt.tight_layout()

# %%
p_by_generator = network.generators_t.p.T.groupby(network.generators.carrier).sum().T / 1e3 # unis of GW

all_colors = config["plotting"]["tech_colors"]

colors = []
for col in p_by_generator.columns:
    try:
        colors.append(all_colors[col])
    except KeyError:
        colors.append("gray")

p_by_generator.rename(columns=config["plotting"]["nice_names"], inplace=True)

fig, ax = plt.subplots(figsize=(12, 6))
p_by_generator.plot(kind="line", ax=ax, color=colors)
ax.legend(ncol=4, loc="upper left")
ax.set_ylabel("GW")
ax.set_xlabel("")
fig.tight_layout()
